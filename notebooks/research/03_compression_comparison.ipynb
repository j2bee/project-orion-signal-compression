# %% [markdown]
# # 03 — Compression Comparison
#
# **Question:** What happens when compression ratio increases across methods?

# %%
import sys
sys.path.insert(0, '../..')
import pandas as pd
import subprocess
subprocess.run(['python3', 'experiments/compression_comparison.py'], cwd='../..')
df = pd.read_csv('../../results/compression_comparison.csv')
df.sort_values('SNR_vs_working_dB', ascending=False).head(10)
