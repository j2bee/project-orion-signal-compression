# %% [markdown]
# # 02 — Noise Analysis
#
# **Question:** How does each noise type affect observed signal quality?

# %%
import sys
sys.path.insert(0, '../..')
from src.data_loader.loader import load_signal
from src.generate_synthetic import create_synthetic_dataset
from src.noise_analysis import run_noise_sweep
path = create_synthetic_dataset()
_, signal, meta = load_signal(path)
results = run_noise_sweep(signal, meta['sampling_frequency'], output_dir='../../results/noise_analysis')
print(results)
